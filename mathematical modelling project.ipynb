# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('observation plastic.csv')
df
# Out:
#     sr_no Identification_no Type_ of_mould   area _of _mould  \
# 0     NaN                R1     rectangular         29900.00
# 1     NaN                B1         hexagon         34359.55
# 2     NaN                B2         hexagon         34359.55
# 3     NaN                B3         hexagon         34359.55
# 4     NaN                B4         hexagon         34359.55
# 5     NaN                R2     rectangular         29900.00
# 6     NaN                R3     rectangular         29900.00
# 7     NaN                R4     rectangular         29900.00
# 8     NaN                B5         hexagon         34359.55
# 9     NaN                B6         hexagon         34359.55
# 10    NaN                B6         hexagon         34359.55
# 11    NaN                B7         hexagon         34359.55
# 12    NaN                B8         hexagon         34359.55
# 13    NaN                B9         hexagon         34359.55
# 14    NaN                R6     rectangular         29900.00
# 15    NaN                R7     rectangular         29900.00
# 16    NaN               B10         hexagon         34359.55
# 17    NaN               B11         hexagon         34359.55
#
#     ingridients_in_paving_sand_In_KG  ingridients_in_paving_plastic_%  Load  \
# 0                              0.695                               50   461
# 1                              1.535                               40   600
# 2                              2.300                               30   999
# 3                              2.300                               55   718
# 4                              2.300                               25   513
# 5                              1.230                               60   190
# 6                              0.600                               51   404
# 7                              2.040                               39   517
# 8                              1.280                               48   579
# 9                              1.950                               22   621
# 10                             2.260                               28   930
# 11                             2.450                               32  1069
# 12                             1.430                               41   603
# 13                             2.480                               29   834
# 14                             1.760                               49   170
# 15                             0.532                               56   220
# 16                             0.714                               49   465
# 17                             1.950                               46   560
#
#     Weight   Compressive_Strength
# 0     1.390                15.410
# 1     2.565                17.462
# 2     3.375                29.070
# 3     2.910                14.930
# 4     3.325                20.890
# 5     3.870                 6.534
# 6     1.220                13.528
# 7     3.350                17.290
# 8     2.470                16.862
# 9     2.510                18.062
# 10    3.140                27.050
# 11    3.610                31.090
# 12    2.440                17.532
# 13    3.500                24.248
# 14    3.460                 5.350
# 15    1.210                 7.358
# 16    1.400                13.560
# 17    3.620                16.300

# %%
# %matplotlib inline
plt.xlabel('Compressive_Strength')
plt.ylabel('ingridients_in_paving_plastic_%')
plt.scatter(df.Compressive_Strength, df.ingridients_in_paving_plastic_, color='red', marker='*')

# %%
print(df.columns)
# Out:
# Index(['sr_no', 'Identification_no', 'Type_ of_mould ', 'area _of _mould',
#        'ingridients_in_paving_sand_In_KG', 'ingridients_in_paving_plastic_%',
#        'Load', 'Weight ', 'Compressive_Strength'],
#       dtype='object')

# %%
# update the column name 'B' to 'C'
df = df.rename(columns={'ingridients_in_paving_plastic_%': 'ingridients_in_paving_plastic_'})

# display the updated column names
print(df.columns)
# Out:
# Index(['sr_no', 'Identification_no', 'Type_ of_mould ', 'area _of _mould',
#        'ingridients_in_paving_sand_In_KG', 'ingridients_in_paving_plastic_',
#        'Load', 'Weight ', 'Compressive_Strength'],
#       dtype='object')

# %%
df
# Out:
#     sr_no Identification_no Type_ of_mould   area _of _mould  \
# 0     NaN                R1     rectangular         29900.00
# 1     NaN                B1         hexagon         34359.55
# 2     NaN                B2         hexagon         34359.55
# 3     NaN                B3         hexagon         34359.55
# 4     NaN                B4         hexagon         34359.55
# 5     NaN                R2     rectangular         29900.00
# 6     NaN                R3     rectangular         29900.00
# 7     NaN                R4     rectangular         29900.00
# 8     NaN                B5         hexagon         34359.55
# 9     NaN                B6         hexagon         34359.55
# 10    NaN                B6         hexagon         34359.55
# 11    NaN                B7         hexagon         34359.55
# 12    NaN                B8         hexagon         34359.55
# 13    NaN                B9         hexagon         34359.55
# 14    NaN                R6     rectangular         29900.00
# 15    NaN                R7     rectangular         29900.00
# 16    NaN               B10         hexagon         34359.55
# 17    NaN               B11         hexagon         34359.55
#
#     ingridients_in_paving_sand_In_KG  ingridients_in_paving_plastic_  Load  \
# 0                              0.695                              50   461
# 1                              1.535                              40   600
# 2                              2.300                              30   999
# 3                              2.300                              55   718
# 4                              2.300                              25   513
# 5                              1.230                              60   190
# 6                              0.600                              51   404
# 7                              2.040                              39   517
# 8                              1.280                              48   579
# 9                              1.950                              22   621
# 10                             2.260                              28   930
# 11                             2.450                              32  1069
# 12                             1.430                              41   603
# 13                             2.480                              29   834
# 14                             1.760                              49   170
# 15                             0.532                              56   220
# 16                             0.714                              49   465
# 17                             1.950                              46   560
#
#     Weight   Compressive_Strength
# 0     1.390                15.410
# 1     2.565                17.462
# 2     3.375                29.070
# 3     2.910                14.930
# 4     3.325                20.890
# 5     3.870                 6.534
# 6     1.220                13.528
# 7     3.350                17.290
# 8     2.470                16.862
# 9     2.510                18.062
# 10    3.140                27.050
# 11    3.610                31.090
# 12    2.440                17.532
# 13    3.500                24.248
# 14    3.460                 5.350
# 15    1.210                 7.358
# 16    1.400                13.560
# 17    3.620                16.300

# %%
new_df = df[['Compressive_Strength', 'ingridients_in_paving_plastic_']]

# %%
new_df
# Out:
#     Compressive_Strength  ingridients_in_paving_plastic_
# 0                 15.410                              50
# 1                 17.462                              40
# 2                 29.070                              30
# 3                 14.930                              55
# 4                 20.890                              25
# 5                  6.534                              60
# 6                 13.528                              51
# 7                 17.290                              39
# 8                 16.862                              48
# 9                 18.062                              22
# 10                27.050                              28
# 11                31.090                              32
# 12                17.532                              41
# 13                24.248                              29
# 14                 5.350                              49
# 15                 7.358                              56
# 16                13.560                              49
# 17                16.300                              46

# %%
n_df = new_df.drop('ingridients_in_paving_plastic_',axis='columns')
n_df
# Out:
#     Compressive_Strength
# 0                 15.410
# 1                 17.462
# 2                 29.070
# 3                 14.930
# 4                 20.890
# 5                  6.534
# 6                 13.528
# 7                 17.290
# 8                 16.862
# 9                 18.062
# 10                27.050
# 11                31.090
# 12                17.532
# 13                24.248
# 14                 5.350
# 15                 7.358
# 16                13.560
# 17                16.300

# %%
ingridients_in_paving_plastic_ = df.ingridients_in_paving_plastic_
ingridients_in_paving_plastic_
# Out:
# 0     50
# 1     40
# 2     30
# 3     55
# 4     25
# 5     60
# 6     51
# 7     39
# 8     48
# 9     22
# 10    28
# 11    32
# 12    41
# 13    29
# 14    49
# 15    56
# 16    49
# 17    46
# Name: ingridients_in_paving_plastic_, dtype: int64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(n_df,ingridients_in_paving_plastic_)
# Out:
# LinearRegression()

# %%
reg.predict([[50]])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.51376515])

# %%
reg.coef_
# Out:
# array([-1.26091066])

# %%
reg.intercept_
# Out:
# 63.55929799792155

# %%
50*-1.26091066+63.55929799792155
# Out:
# 0.5137649979215482

# %%
plt.figure(figsize = (15,9))

sns.scatterplot(data = df, x = 'Compressive_Strength', y = 'ingridients_in_paving_plastic_')
# Out:
# <AxesSubplot:xlabel='Compressive_Strength', ylabel='ingridients_in_paving_plastic_'>

# %%
sns.countplot(data=new_df, x='Compressive_Strength', y='ingridients_in_paving_plastic')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27716/1020992346.py in <module>
# ----> 1 sns.countplot(data=new_df, x='Compressive_Strength', y='ingridients_in_paving_plastic')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3594         y = x
#    3595     elif x is not None and y is not None:
# -> 3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
#    3598     plotter = _CountPlotter(
#
# ValueError: Cannot pass values for both `x` and `y`
